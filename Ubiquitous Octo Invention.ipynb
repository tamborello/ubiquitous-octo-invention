# %% [markdown]
# <h1>Ubiquitous Octo Invention</h1>
# Demonstrates semantic search from visual feature and entity tags from a photo. We'll use the [JFK Assassination Records](https://www.archives.gov/research/jfk/release).

# %% [markdown]
# First: how to get the URLs out of the JFK document project's Excel spreadsheet? [openpyxl](https://openpyxl.readthedocs.io/en/stable/tutorial.html)

# %% [markdown]
# <h2>Download the Documents</h2>

# %%
from openpyxl import load_workbook
jfkIndex = load_workbook(filename = 'jfk.xlsx')
# sheet_ranges = jfkIndex['Worksheet']
# for cell in jfkIndex['A2':'A10']:

# %%
type(jfkIndex['Worksheet']['A2'])
# Out:
# openpyxl.cell.cell.Cell

# %%
# This will fail if there is no hyperlink to target
try:
    url = jfkIndex['Worksheet']['A2'].hyperlink.target
except Exception as exc:
    print(exc)
url
# Out:
# 'https://www.archives.gov/files/research/jfk/releases/2018/104-10196-100270001.pdf'

# %%
jfkIndex['Worksheet']['A2'].value
# Out:
# '2018/104-10196-100270001.pdf'

# %%
urlBase = 'https://www.archives.gov/files/research/jfk/releases/'

# %%
import requests
from pathlib import Path
from utils.whoopsie import whoopsie

def savePDF (fn, pdf):
    with open(fn, 'wb') as f:
        f.write(pdf)

# %%
with requests.Session() as session:
    with session.get('https://www.archives.gov/files/research/jfk/releases/2018/104-10196-100270001.pdf', stream=True) as conn:
        savePDF('docs/' + 'test.pdf', conn.content)

# %%
"docs/" + jfkIndex['Worksheet']['A2'].value
# Out:
# 'docs/2018/104-10196-100270001.pdf'

# %%
with requests.Session() as session:
    for c in range(10002,54637):
        cell = "A" + str(c)
        url = jfkIndex['Worksheet'][cell].hyperlink.target
        filename = jfkIndex['Worksheet'][cell].value
        with session.get(url, timeout=300) as conn:
            try:
                savePDF("docs2/" + filename, conn.content)
            except Exception as exc:
                whoopsie(str(exc) + " " + url)

# %%
# That's the end of the column
jfkIndex["Worksheet"]["A54637"].hyperlink.target
# Out:
# 'https://www.archives.gov/files/research/jfk/releases/docid-32404866.pdf'

# %% [markdown]
# <h2>Trim the Text Quality Distribution</h2>
# A lot of these images are poor quality, leading to fairly unintelligible text documents. How can I assess the "intelligibleness" of a document and trim the distribution of documents to, say, the best 1/5?

# %% [markdown]
# <h2>OCR the Image PDFs</h2>
# The PDFs are all image PDFs! There's no text!
#
# pdf2image or [Azure OCR](https://docs.microsoft.com/en-us/azure/cognitive-services/computer-vision/quickstarts-sdk/client-library?tabs=visual-studio&pivots=programming-language-python)?

# %% [markdown]
# <h3>OCR Remotely</h3>
# Azure Computer Vision

# %%
from azure.cognitiveservices.vision.computervision import ComputerVisionClient
from azure.cognitiveservices.vision.computervision.models import OperationStatusCodes
from azure.cognitiveservices.vision.computervision.models import VisualFeatureTypes
from msrest.authentication import CognitiveServicesCredentials

from array import array
import os
from PIL import Image
import sys
import time

'''
Authenticate
Authenticates your credentials and creates a client.
'''
subscription_key = ""
endpoint = ""

computervision_client = ComputerVisionClient(endpoint, CognitiveServicesCredentials(subscription_key))

# %%
'''
OCR: Read File using the Read API, extract text - remote
This example will extract text in an image, then print results, line by line.
This API call can also extract handwriting style text (not shown).

You can also read text from a local image. See the 
ComputerVisionClientOperationsMixin methods, such as read_in_stream. 
Or, see the sample code on GitHub for scenarios involving local images.


'''
print("===== Read File - remote =====")
# Get an image with text
# read_image_url = "https://raw.githubusercontent.com/MicrosoftDocs/azure-docs/master/articles/cognitive-services/Computer-vision/Images/readsample.jpg"
read_image_url = "https://www.archives.gov/files/research/jfk/releases/2018/104-10196-100270001.pdf"

# Call API with URL and raw response (allows you to get the operation location)
read_response = computervision_client.read(read_image_url,  raw=True)
# Out:
# ===== Read File - remote =====

# %%
# Get the operation location (URL with an ID at the end) from the response
read_operation_location = read_response.headers["Operation-Location"]
# Grab the ID from the URL
operation_id = read_operation_location.split("/")[-1]

# Call the "GET" API and wait for it to retrieve the results 
while True:
    read_result = computervision_client.get_read_result(operation_id)
    if read_result.status not in ['notStarted', 'running']:
        break
    time.sleep(1)

# Print the detected text, line by line
if read_result.status == OperationStatusCodes.succeeded:
    for text_result in read_result.analyze_result.read_results:
        for line in text_result.lines[:10]:
            print(line.text)
            # print(line.bounding_box)
print()
# Out:
# JFK Assassination System
# Date:
# 5/2/2018
# Identification Form
# Agency Information
# AGENCY :
# CIA
# RECORD NUMBER :
# 104-10196-10027
# RECORD SERIES :
# CIA HISTORICAL REVIEW PROGRAM
# RELEASE IN FULL 1998.
# CIA ACTIVITIES AND THE WARREN COMMISSION INVESTIGATION
# SUMMARY
# There is a need to investigate the role of the CIA and the FBI in the
# investigation of the assassination of President Kennedy, and their relation-
# ships.with Lee Harvey Oswald. Since several agencies had files on Oswald which
# can be checked against each other, a useful case study of CIA practices is
# possible. These records should shed light on the interception of mail to Russia,
# CIA concern about (and file-keeping on) domestic political activities, and other

# %%
def extract_doc (read_image_url, filename) : 
    # Call API with URL and raw response (allows you to get the operation location)
    read_response = computervision_client.read(read_image_url,  raw=True)
    # Get the operation location (URL with an ID at the end) from the response
    read_operation_location = read_response.headers["Operation-Location"]
    # Grab the ID from the URL
    operation_id = read_operation_location.split("/")[-1]

    # Call the "GET" API and wait for it to retrieve the results 
    while True:
        read_result = computervision_client.get_read_result(operation_id)
        if read_result.status not in ['notStarted', 'running']:
            break
        time.sleep(1)

    # Save the detected text
    doc = ""

    if read_result.status == OperationStatusCodes.succeeded:
        for text_result in read_result.analyze_result.read_results:
            for line in text_result.lines:
                doc = doc + line.text

    with open(filename, 'w') as f:
        f.write(doc)

# extract_doc(read_image_url, "extracted_docs/104-10196-100270001.txt")

# %%
def ocr_docs () :

    with requests.Session() as session:
        for c in range(3,4982):
            cell = "A" + str(c)
            url = jfkIndex['Worksheet'][cell].hyperlink.target
            filename = jfkIndex['Worksheet'][cell].value
            filename = filename[:-4] + '.txt'
            with session.get(url, timeout=300) as conn:
                try:
                    extract_doc(url, "acs_extracted_docs/" + filename)
                except Exception as exc:
                    whoopsie(str(exc) + " " + url)

# %%
ocr_docs()
# Out:
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32269709.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/194-10013-10448.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/144-10001-10195_docid_6606912_binary_sealed.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/144-10001-10288_docid_6607058_binary_sealed.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/144-10001-10127_docid_6606147_binary_sealed.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/144-10001-10176_docid_6606900_binary_sealed.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/144-10001-10206_docid_6606914_binary_sealed.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/144-10001-10125_docid_6606039_binary_sealed.pdf
# 'charmap' codec can't encode character '\u212e' in position 1586: character maps to <undefined> https://www.archives.gov/files/research/jfk/releases/2018/docid-32267020.pdf
# 'charmap' codec can't encode character '\u0118' in position 491: character maps to <undefined> https://www.archives.gov/files/research/jfk/releases/2018/docid-32269615.pdf
# 'charmap' codec can't encode character '\u20b8' in position 1601: character maps to <undefined> https://www.archives.gov/files/research/jfk/releases/2018/docid-32269624.pdf
# 'charmap' codec can't encode character '\u20aa' in position 4279: character maps to <undefined> https://www.archives.gov/files/research/jfk/releases/2018/docid-32269628.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/180-10131-10327.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/180-10131-10324.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32267370.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32266807.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32245535.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32248477.pdf
# 'charmap' codec can't encode character '\u015e' in position 592: character maps to <undefined> https://www.archives.gov/files/research/jfk/releases/2018/124-10048-10267.pdf
# 'charmap' codec can't encode character '\u017c' in position 1784: character maps to <undefined> https://www.archives.gov/files/research/jfk/releases/2018/docid-32279253.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32284185.pdf
# 'charmap' codec can't encode character '\u015e' in position 1602: character maps to <undefined> https://www.archives.gov/files/research/jfk/releases/2018/docid-32161095.pdf
# 'charmap' codec can't encode character '\u017c' in position 1750: character maps to <undefined> https://www.archives.gov/files/research/jfk/releases/2018/docid-32164547.pdf
# 'charmap' codec can't encode character '\u212e' in position 2323: character maps to <undefined> https://www.archives.gov/files/research/jfk/releases/2018/124-10157-10037.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989700.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989641.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989641.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989711.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989560.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989560.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989560.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989560.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989640.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989640.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989640.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989749.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989749.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989749.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989749.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989749.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989749.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989749.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989749.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989749.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989749.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989749.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989749.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989749.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989749.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989749.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989749.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989749.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989749.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989503.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989503.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989503.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989503.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989503.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989570.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989570.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989570.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989570.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989570.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989570.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989570.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989570.pdf
# 'charmap' codec can't encode character '\u897f' in position 480: character maps to <undefined> https://www.archives.gov/files/research/jfk/releases/2018/docid-32989732.pdf
# 'charmap' codec can't encode character '\u897f' in position 480: character maps to <undefined> https://www.archives.gov/files/research/jfk/releases/2018/docid-32989732.pdf
# 'charmap' codec can't encode character '\u897f' in position 480: character maps to <undefined> https://www.archives.gov/files/research/jfk/releases/2018/docid-32989732.pdf
# 'charmap' codec can't encode character '\u897f' in position 480: character maps to <undefined> https://www.archives.gov/files/research/jfk/releases/2018/docid-32989732.pdf
# 'charmap' codec can't encode character '\u897f' in position 480: character maps to <undefined> https://www.archives.gov/files/research/jfk/releases/2018/docid-32989732.pdf
# 'charmap' codec can't encode character '\u897f' in position 480: character maps to <undefined> https://www.archives.gov/files/research/jfk/releases/2018/docid-32989732.pdf
# 'charmap' codec can't encode character '\u897f' in position 480: character maps to <undefined> https://www.archives.gov/files/research/jfk/releases/2018/docid-32989732.pdf
# 'charmap' codec can't encode character '\u897f' in position 480: character maps to <undefined> https://www.archives.gov/files/research/jfk/releases/2018/docid-32989732.pdf
# 'charmap' codec can't encode character '\u897f' in position 480: character maps to <undefined> https://www.archives.gov/files/research/jfk/releases/2018/docid-32989732.pdf
# 'charmap' codec can't encode character '\u897f' in position 480: character maps to <undefined> https://www.archives.gov/files/research/jfk/releases/2018/docid-32989732.pdf
# 'charmap' codec can't encode character '\u897f' in position 480: character maps to <undefined> https://www.archives.gov/files/research/jfk/releases/2018/docid-32989732.pdf
# 'charmap' codec can't encode character '\u897f' in position 480: character maps to <undefined> https://www.archives.gov/files/research/jfk/releases/2018/docid-32989732.pdf
# 'charmap' codec can't encode character '\u897f' in position 480: character maps to <undefined> https://www.archives.gov/files/research/jfk/releases/2018/docid-32989732.pdf
# 'charmap' codec can't encode character '\u897f' in position 480: character maps to <undefined> https://www.archives.gov/files/research/jfk/releases/2018/docid-32989732.pdf
# 'charmap' codec can't encode character '\u897f' in position 480: character maps to <undefined> https://www.archives.gov/files/research/jfk/releases/2018/docid-32989732.pdf
# 'charmap' codec can't encode character '\u897f' in position 480: character maps to <undefined> https://www.archives.gov/files/research/jfk/releases/2018/docid-32989732.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989751.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989751.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989751.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989751.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989751.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989751.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989751.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989751.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989751.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989751.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989751.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989751.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989751.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989751.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989751.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989751.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989748.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989748.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989748.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989748.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989748.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989748.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989748.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989748.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989748.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989748.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989748.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989748.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989748.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989748.pdf
# 'charmap' codec can't encode character '\u015e' in position 2138: character maps to <undefined> https://www.archives.gov/files/research/jfk/releases/2018/docid-32175952.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989603.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989603.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989603.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989603.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989603.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989587.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989587.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989587.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989587.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989595.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989750.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989750.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989750.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989750.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989750.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989750.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989750.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989750.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989750.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989750.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989750.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989750.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989750.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989750.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989750.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989750.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989750.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/124-10184-10329.pdf
# 'charmap' codec can't encode character '\u20b1' in position 852: character maps to <undefined> https://www.archives.gov/files/research/jfk/releases/2018/docid-32176435.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989738.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989738.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989738.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989738.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989738.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989738.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989738.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989738.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989738.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989738.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989738.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989738.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989738.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989738.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989820.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989802.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989802.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989802.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989802.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989802.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989802.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/124-10185-10281.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989543.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989602.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989602.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989602.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989602.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989602.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989823.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989823.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989823.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989499.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989499.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989595.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989595.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989595.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989595.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989595.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989595.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989560.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989753.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989753.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989753.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989753.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989753.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989753.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989753.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989753.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989753.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989753.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989753.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989753.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989753.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989740.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/124-10188-10205.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989740.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989740.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989740.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989740.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989740.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989740.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989740.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989740.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989740.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989740.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989740.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989740.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989734.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989734.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989734.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989734.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989734.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989734.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989734.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989734.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989734.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989799.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989799.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989799.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989807.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989817.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989817.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989767.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989529.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989503.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989503.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989503.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32989632.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32177781.pdf
# 'charmap' codec can't encode character '\u010c' in position 530: character maps to <undefined> https://www.archives.gov/files/research/jfk/releases/2018/docid-32285866.pdf
# 'charmap' codec can't encode character '\u0164' in position 1923: character maps to <undefined> https://www.archives.gov/files/research/jfk/releases/2018/docid-32286617.pdf
# 'charmap' codec can't encode character '\u0105' in position 1347: character maps to <undefined> https://www.archives.gov/files/research/jfk/releases/2018/docid-32286805.pdf
# 'charmap' codec can't encode character '\u20bd' in position 1597: character maps to <undefined> https://www.archives.gov/files/research/jfk/releases/2018/docid-32287170.pdf
# 'charmap' codec can't encode character '\u010c' in position 1808: character maps to <undefined> https://www.archives.gov/files/research/jfk/releases/2018/docid-32287523.pdf
# 'charmap' codec can't encode character '\u0158' in position 1909: character maps to <undefined> https://www.archives.gov/files/research/jfk/releases/2018/docid-32288043.pdf
# 'charmap' codec can't encode character '\u0118' in position 116: character maps to <undefined> https://www.archives.gov/files/research/jfk/releases/2018/docid-32288490.pdf
# 'charmap' codec can't encode character '\u20b9' in position 1424: character maps to <undefined> https://www.archives.gov/files/research/jfk/releases/2018/docid-32288584.pdf
# 'charmap' codec can't encode character '\u0130' in position 2800: character maps to <undefined> https://www.archives.gov/files/research/jfk/releases/2018/docid-32289108.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32289115.pdf
# 'charmap' codec can't encode character '\u20b1' in position 508: character maps to <undefined> https://www.archives.gov/files/research/jfk/releases/2018/docid-32289193.pdf
# 'charmap' codec can't encode character '\u010d' in position 541: character maps to <undefined> https://www.archives.gov/files/research/jfk/releases/2018/docid-32289194.pdf
# 'charmap' codec can't encode character '\u0141' in position 1622: character maps to <undefined> https://www.archives.gov/files/research/jfk/releases/2018/docid-32289518.pdf
# 'charmap' codec can't encode character '\u0104' in position 1023: character maps to <undefined> https://www.archives.gov/files/research/jfk/releases/2018/docid-32585253.pdf
# 'charmap' codec can't encode character '\u20a3' in position 407: character maps to <undefined> https://www.archives.gov/files/research/jfk/releases/2018/docid-32576744.pdf
# 'charmap' codec can't encode character '\u20a5' in position 3994: character maps to <undefined> https://www.archives.gov/files/research/jfk/releases/2018/docid-32557728.pdf
# 'charmap' codec can't encode character '\u17db' in position 2923: character maps to <undefined> https://www.archives.gov/files/research/jfk/releases/2018/docid-32560419.pdf
# 'charmap' codec can't encode character '\u20a6' in position 2240: character maps to <undefined> https://www.archives.gov/files/research/jfk/releases/2018/docid-32578797.pdf
# 'charmap' codec can't encode character '\u0119' in position 4: character maps to <undefined> https://www.archives.gov/files/research/jfk/releases/2018/docid-32561576.pdf
# 'charmap' codec can't encode character '\u5b9a' in position 57: character maps to <undefined> https://www.archives.gov/files/research/jfk/releases/2018/docid-32561563.pdf
# 'charmap' codec can't encode character '\u0131' in position 75: character maps to <undefined> https://www.archives.gov/files/research/jfk/releases/2018/docid-32561559.pdf
# 'charmap' codec can't encode character '\u09f3' in position 857: character maps to <undefined> https://www.archives.gov/files/research/jfk/releases/2018/docid-32556620.pdf
# 'charmap' codec can't encode character '\u015e' in position 1260: character maps to <undefined> https://www.archives.gov/files/research/jfk/releases/2018/docid-32556632.pdf
# 'charmap' codec can't encode character '\u0141' in position 1544: character maps to <undefined> https://www.archives.gov/files/research/jfk/releases/2018/docid-32556648.pdf
# 'charmap' codec can't encode character '\u20a6' in position 1144: character maps to <undefined> https://www.archives.gov/files/research/jfk/releases/2018/docid-32556684.pdf
# 'charmap' codec can't encode character '\u17db' in position 1524: character maps to <undefined> https://www.archives.gov/files/research/jfk/releases/2018/docid-32556685.pdf
# 'charmap' codec can't encode character '\u212e' in position 0: character maps to <undefined> https://www.archives.gov/files/research/jfk/releases/2018/docid-32556692.pdf
# 'charmap' codec can't encode character '\u20b9' in position 926: character maps to <undefined> https://www.archives.gov/files/research/jfk/releases/2018/docid-32556714.pdf
# 'charmap' codec can't encode character '\u058f' in position 443: character maps to <undefined> https://www.archives.gov/files/research/jfk/releases/2018/docid-32556717.pdf
# 'charmap' codec can't encode character '\u0164' in position 1123: character maps to <undefined> https://www.archives.gov/files/research/jfk/releases/2018/docid-32556718.pdf
# 'charmap' codec can't encode character '\u20be' in position 134: character maps to <undefined> https://www.archives.gov/files/research/jfk/releases/2018/docid-32563819.pdf
# 'charmap' codec can't encode character '\u017b' in position 714: character maps to <undefined> https://www.archives.gov/files/research/jfk/releases/2018/docid-32563816.pdf
# 'charmap' codec can't encode character '\u011a' in position 289: character maps to <undefined> https://www.archives.gov/files/research/jfk/releases/2018/docid-32563719.pdf
# 'charmap' codec can't encode character '\u015e' in position 1134: character maps to <undefined> https://www.archives.gov/files/research/jfk/releases/2018/docid-32563716.pdf
# Operation returned an invalid status code 'Bad Request' https://www.archives.gov/files/research/jfk/releases/2018/docid-32568032.pdf
# 'charmap' codec can't encode character '\u20ba' in position 3550: character maps to <undefined> https://www.archives.gov/files/research/jfk/releases/2018/docid-32576612.pdf
# 'charmap' codec can't encode character '\u20aa' in position 1467: character maps to <undefined> https://www.archives.gov/files/research/jfk/releases/2018/docid-32578774.pdf
# 'charmap' codec can't encode character '\u20a3' in position 481: character maps to <undefined> https://www.archives.gov/files/research/jfk/releases/2018/docid-32290345-1.pdf
# 'charmap' codec can't encode character '\u0106' in position 618: character maps to <undefined> https://www.archives.gov/files/research/jfk/releases/2018/docid-32290701-1.pdf
# 'charmap' codec can't encode character '\u2103' in position 1653: character maps to <undefined> https://www.archives.gov/files/research/jfk/releases/2018/docid-32290857-1.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/docid-32290930-1.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/docid-32290937-1.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/docid-32290939-1.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/docid-32290940-1.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/docid-32290941-1.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/docid-32290944-1.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/docid-32290946-1.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/docid-32290949-1.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/docid-32290952-1.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/docid-32290953-1.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/docid-32290962-1.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/docid-32291007-1.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/docid-32291013-1.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/docid-32291020-1.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/docid-32291021-1.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/docid-32291029-1.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/docid-32291034-1.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/docid-32291037-1.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/docid-32291076-1.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/docid-32291077-1.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/docid-32291098-1.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/docid-32291139-1.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/docid-32291247-1.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/docid-32291260-1.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/docid-32291274-1.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/docid-32291278-1.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/docid-32291279-1.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/124-10207-10057.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/docid-32291284-1.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/docid-32291292-1.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/docid-32291302-1.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/docid-32291305-1.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/docid-32291309-1.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/docid-32291312-1.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/docid-32291326-1.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/docid-32291341-1.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/docid-32291351-1.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/docid-32291368-1.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/docid-32291384-1.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/docid-32291385-1.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/docid-32291386-1.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/docid-32291392-1.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/docid-32291393-1.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/docid-32291395-1.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/docid-32291398-1.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/docid-32291399-1.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/docid-32291401-1.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/docid-32291402-1.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/docid-32291407-1.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/docid-32291417-1.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/docid-32291418-1.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/docid-32291419-1.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/docid-32291420-1.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/docid-32291422-1.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/docid-32291423-1.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/docid-32291485-1.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/docid-32291501-1.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/docid-32291542-1.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/docid-32291579-1.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/docid-32291640-1.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/docid-32291663-1.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/docid-32291719-1.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/docid-32291720-1.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/docid-32291731-1.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/docid-32291736-1.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/docid-32291750-1.pdf
# ...
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10253.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10258.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10261.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10266.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10271.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10272.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10275.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10276.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10277.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10280.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10281.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10283.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10284.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10285.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10286.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10287.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10288.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10290.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10293.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10296.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10298.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10299.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10301.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10303.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10307.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10310.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10312.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10313.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10314.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10320.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10321.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10322.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10323.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10332.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10333.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10336.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10338.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10339.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10342.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10343.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10344.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10345.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10346.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10350.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10354.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10356.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10357.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10358.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10359.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10360.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10364.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10365.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10367.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10368.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10369.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10370.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10371.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10375.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10377.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10380.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10382.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10384.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10385.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10386.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10387.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10387_1.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10390.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10392.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10393.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10394.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10395.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10396.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10397.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10400.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10401.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10402.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10403.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10404.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10407.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10408.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10412.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10413.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10417.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10418.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10419.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10420.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10423.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10424.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10425.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10426.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10427.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10431.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10435.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10436.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10437.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10440.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10441.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10443.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10445.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10446.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10077-10449.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10078-10000.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10078-10001.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10078-10002.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10078-10003.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10078-10005.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10078-10006.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10078-10007.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10078-10009.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10078-10010.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10078-10012.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10078-10013.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10078-10014.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10078-10014_1.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10078-10015.pdf
# Operation returned an invalid status code 'Quota Exceeded' https://www.archives.gov/files/research/jfk/releases/2018/104-10078-10017.pdf

# %% [markdown]
# Aww damn! The free computer vision service maxes out at 5K transactions/month! The next up, S1, would suffice and would cost a few tens of dollars. [Pricing - Computer Vision API](https://azure.microsoft.com/en-us/pricing/details/cognitive-services/computer-vision/)
